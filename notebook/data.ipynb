# %%
import pandas as pd

# %%
log_raw = pd.read_csv('/home/zseefvhu12/projects/spark_training/data/samples/raw/01-log-tracking-sample.csv')
purchase_raw = pd.read_csv('/home/zseefvhu12/projects/spark_training/data/samples/raw/02-purchase-behavior-sample.csv')
log_bronze = pd.read_csv('/home/zseefvhu12/projects/spark_training/data/samples/bronze/log_tracking_sample.csv')
purchase_bronze = pd.read_csv('/home/zseefvhu12/projects/spark_training/data/samples/bronze/purchase_behavior_sample.csv')

# %%
log_raw.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 08:00:00 UTC       view     1000000  2053013555631882655
# 1  2019-11-01 08:17:00 UTC       cart     1000001  2053013554415534427
# 2  2019-11-01 08:34:00 UTC   purchase     1000002  2053013554658804075
# 3  2019-11-01 08:51:00 UTC       view     1000003  2053013557192163841
# 4  2019-11-01 09:08:00 UTC       cart     1000004  2053013555631882655
#
#             category_code    brand  price    user_id        user_session
# 0  electronics.smartphone  samsung  19.99  520000000  sample-session-000
# 1      computers.notebook    apple  27.49  520000001  sample-session-001
# 2      appliances.kitchen   xiaomi  34.99  520000002  sample-session-002
# 3   furniture.bedroom.bed     sony  42.49  520000003  sample-session-003
# 4  electronics.smartphone       lg  49.99  520000004  sample-session-004

# %%
purchase_raw.head()
# Out:
#      user_id           event_time event_type  product_id          category_id  \
# 0  520000000  2019-11-01 08:00:00   purchase     1000000  2053013555631882655
# 1  520000001  2019-11-01 08:17:00       cart     1000001  2053013554415534427
# 2  520000002  2019-11-01 08:34:00   purchase     1000002  2053013554658804075
# 3  520000003  2019-11-01 08:51:00   purchase     1000003  2053013557192163841
# 4  520000004  2019-11-01 09:08:00       cart     1000004  2053013555631882655
#
#             category_code    brand  price        user_session  event_date  \
# 0  electronics.smartphone  samsung  19.99  sample-session-000  2019-11-01
# 1      computers.notebook    apple  27.49  sample-session-001  2019-11-01
# 2      appliances.kitchen   xiaomi  34.99  sample-session-002  2019-11-01
# 3   furniture.bedroom.bed     sony  42.49  sample-session-003  2019-11-01
# 4  electronics.smartphone       lg  49.99  sample-session-004  2019-11-01
#
# ...

# %%
log_bronze.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 08:00:00 UTC       view     1000000  2053013555631882655
# 1  2019-11-01 08:17:00 UTC       cart     1000001  2053013554415534427
# 2  2019-11-01 08:34:00 UTC   purchase     1000002  2053013554658804075
# 3  2019-11-01 08:51:00 UTC       view     1000003  2053013557192163841
# 4  2019-11-01 09:08:00 UTC       cart     1000004  2053013555631882655
#
#             category_code    brand  price    user_id        user_session  \
# 0  electronics.smartphone  samsung  19.99  520000000  sample-session-000
# 1      computers.notebook    apple  27.49  520000001  sample-session-001
# 2      appliances.kitchen   xiaomi  34.99  520000002  sample-session-002
# 3   furniture.bedroom.bed     sony  42.49  520000003  sample-session-003
# 4  electronics.smartphone       lg  49.99  520000004  sample-session-004
#
#        event_timestamp  event_date                   source_file  \
# ...

# %%
purchase_bronze.head()
# Out:
#             event_time event_type  product_id          category_id  \
# 0  2019-11-01 08:00:00   purchase     1000000  2053013555631882655
# 1  2019-11-01 08:17:00       cart     1000001  2053013554415534427
# 2  2019-11-01 08:34:00   purchase     1000002  2053013554658804075
# 3  2019-11-01 08:51:00   purchase     1000003  2053013557192163841
# 4  2019-11-01 09:08:00       cart     1000004  2053013555631882655
#
#             category_code    brand  price    user_id        user_session  \
# 0  electronics.smartphone  samsung  19.99  520000000  sample-session-000
# 1      computers.notebook    apple  27.49  520000001  sample-session-001
# 2      appliances.kitchen   xiaomi  34.99  520000002  sample-session-002
# 3   furniture.bedroom.bed     sony  42.49  520000003  sample-session-003
# 4  electronics.smartphone       lg  49.99  520000004  sample-session-004
#
#        event_timestamp  ... first_event_date start_of_week week_number  \
# ...

# %%
log_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_time     100 non-null    str
#  1   event_type     100 non-null    str
#  2   product_id     100 non-null    int64
#  3   category_id    100 non-null    int64
#  4   category_code  100 non-null    str
#  5   brand          100 non-null    str
#  6   price          100 non-null    float64
#  7   user_id        100 non-null    int64
#  8   user_session   100 non-null    str
# dtypes: float64(1), int64(3), str(5)
# memory usage: 7.2 KB

# %%
purchase_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            100 non-null    int64
#  1   event_time         100 non-null    str
#  2   event_type         100 non-null    str
#  3   product_id         100 non-null    int64
#  4   category_id        100 non-null    int64
#  5   category_code      100 non-null    str
#  6   brand              100 non-null    str
#  7   price              100 non-null    float64
#  8   user_session       100 non-null    str
#  9   event_date         100 non-null    str
#  10  first_event_date   100 non-null    str
#  11  start_of_week      100 non-null    str
#  12  week_number        100 non-null    int64
#  13  end_of_week        100 non-null    str
#  14  week_text          100 non-null    str
#  15  cohort_index_week  100 non-null    str
#  16  week_after         100 non-null    int64
# ...

# %%
log_bronze.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   event_time       100 non-null    str
#  1   event_type       100 non-null    str
#  2   product_id       100 non-null    int64
#  3   category_id      100 non-null    int64
#  4   category_code    100 non-null    str
#  5   brand            100 non-null    str
#  6   price            100 non-null    float64
#  7   user_id          100 non-null    int64
#  8   user_session     100 non-null    str
#  9   event_timestamp  100 non-null    str
#  10  event_date       100 non-null    str
#  11  source_file      100 non-null    str
#  12  ingest_time      100 non-null    str
#  13  batch_id         100 non-null    str
# dtypes: float64(1), int64(3), str(10)
# memory usage: 11.1 KB

# %%
purchase_bronze.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_time         100 non-null    str
#  1   event_type         100 non-null    str
#  2   product_id         100 non-null    int64
#  3   category_id        100 non-null    int64
#  4   category_code      100 non-null    str
#  5   brand              100 non-null    str
#  6   price              100 non-null    float64
#  7   user_id            100 non-null    int64
#  8   user_session       100 non-null    str
#  9   event_timestamp    100 non-null    str
#  10  event_date         100 non-null    str
#  11  first_event_date   100 non-null    str
#  12  start_of_week      100 non-null    str
#  13  week_number        100 non-null    int64
#  14  end_of_week        100 non-null    str
#  15  week_text          100 non-null    str
#  16  cohort_index_week  100 non-null    str
# ...

# %%
data_quality_raw = pd.read_csv('/home/zseefvhu12/projects/spark_training/results/data_profiles.csv')
data_quality.head(40)
# Out:
#              run_id layer            dataset        column_name data_type  \
# 0   20260616_040855   raw       log_tracking         event_time    string
# 1   20260616_040855   raw       log_tracking         event_type    string
# 2   20260616_040855   raw       log_tracking         product_id    string
# 3   20260616_040855   raw       log_tracking        category_id    string
# 4   20260616_040855   raw       log_tracking      category_code    string
# 5   20260616_040855   raw       log_tracking              brand    string
# 6   20260616_040855   raw       log_tracking              price    string
# 7   20260616_040855   raw       log_tracking            user_id    string
# 8   20260616_040855   raw       log_tracking       user_session    string
# 9   20260616_040855   raw  purchase_behavior            user_id    string
# 10  20260616_040855   raw  purchase_behavior         event_time    string
# 11  20260616_040855   raw  purchase_behavior         event_type    string
# ...

# %%
data_quality_bronze = pd.read_csv('/home/zseefvhu12/projects/spark_training/results/bronze_data_profiles.csv')
data_quality_bronze.head(40)
# Out:
#              run_id   layer            dataset        column_name  data_type  \
# 0   20260616_071837  bronze       log_tracking         event_time     string
# 1   20260616_071837  bronze       log_tracking         event_type     string
# 2   20260616_071837  bronze       log_tracking         product_id     string
# 3   20260616_071837  bronze       log_tracking        category_id     string
# 4   20260616_071837  bronze       log_tracking      category_code     string
# 5   20260616_071837  bronze       log_tracking              brand     string
# 6   20260616_071837  bronze       log_tracking              price     string
# 7   20260616_071837  bronze       log_tracking            user_id     string
# 8   20260616_071837  bronze       log_tracking       user_session     string
# 9   20260616_071837  bronze       log_tracking    event_timestamp  timestamp
# 10  20260616_071837  bronze       log_tracking         event_date       date
# ...
